# %% [markdown]
# # Uniswap V3 Subgraph Liquidity Positions Example
#
# This notebook is just the `.ipynb` (for easier reading of both code and output on github) implementation of [this code](https://github.com/atiselsts/uniswap-v3-liquidity-math/blob/master/subgraph-liquidity-positions-example.py) (credit: https://github.com/atiselsts) with slight modifications, showing an example on how to query the Uniswap v3 Subgraph to show all active positions in the USDC/WETH 0.3% pool.
#
# See the technical note [Liquidity Math in Uniswap v3](http://atiselsts.github.io/pdfs/uniswap-v3-liquidity-math.pdf), [Uniswap v3 whitepaper](https://uniswap.org/whitepaper-v3.pdf), and [Uniswap V3 Subgraph](https://thegraph.com/legacy-explorer/subgraph/uniswap/uniswap-v3) for more details.
#
# **Library dependency**: The code uses `gql` to query the Uniswap V3 Subgraph API.

# %%
# Example that shows all active positions in the 0.3% USDC/ETH
# pool using data from the Uniswap v3 subgraph.

from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import math

# 0.3% USDC/ETH pool
POOL_ID = "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8"

# If you want to test with a smaller pool:
# 0.05% GUSD/DAI pool (small pool)
#POOL_ID = "0x7cf12cef5ce9e5e068ebdef470ff8295e26c47b9"

URL = "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3"

pool_query = """query get_pools($pool_id: ID!) {
  pools(where: {id: $pool_id}) {
    tick
    sqrtPrice
    liquidity
    feeTier
    token0 {
      symbol
      decimals
    }
    token1 {
      symbol
      decimals
    }
  }
}"""

# return open positions only (with liquidity > 0)
position_query = """query get_positions($num_skip: Int, $pool_id: ID!) {
  positions(skip: $num_skip, where: {pool: $pool_id, liquidity_gt: 0}) {
    id
    tickLower { tickIdx }
    tickUpper { tickIdx }
    liquidity
  }
}"""

block_query = """query {
  _meta {
    block {
      number
    }
  }
}"""

# %%
TICK_BASE = 1.0001

def tick_to_price(tick):
    return TICK_BASE ** tick

# %%
client = Client(
    transport=RequestsHTTPTransport(
        url=URL,
        verify=True,
        retries=5,
    ))

# %%
# get position info
positions = []
num_skip = 0
try:
    while True:
        #print("Querying positions, num_skip={}".format(num_skip))
        variables = {"num_skip": num_skip, "pool_id": POOL_ID}
        response = client.execute(gql(position_query), variable_values=variables)

        if len(response["positions"]) == 0:
            break
        num_skip += len(response["positions"])
        for item in response["positions"]:
            tick_lower = int(item["tickLower"]["tickIdx"])
            tick_upper = int(item["tickUpper"]["tickIdx"])
            liquidity = int(item["liquidity"])
            id = int(item["id"])
            positions.append((tick_lower, tick_upper, liquidity, id))
except Exception as ex:
    print("got exception while querying position data:", ex)
    exit(-1)

print("Total number of positions found = {}".format(len(positions)))
# Out:
# Total number of positions found = 3552

# %%
try:
    variables = {"pool_id": POOL_ID}
    response = client.execute(gql(pool_query), variable_values=variables)

    if len(response['pools']) == 0:
        print("pool not found")
        exit(-1)

    pool = response['pools'][0]
    pool_liquidity = int(pool["liquidity"])
    current_tick = int(pool["tick"])

    token0 = pool["token0"]["symbol"]
    token1 = pool["token1"]["symbol"]
    decimals0 = int(pool["token0"]["decimals"])
    decimals1 = int(pool["token1"]["decimals"])
except Exception as ex:
    print("got exception while querying pool data:", ex)
    exit(-1)

# %%
# get block height, for record
try:
    response = client.execute(gql(block_query))
    blocknum = response['_meta']['block']['number']
    print("Ethereum block height {}".format(blocknum))
except Exception as ex:
    print("got exception", ex)
# Out:
# Ethereum block height 13339848

# %%
# Compute and print the current price
current_price = tick_to_price(current_tick)
current_sqrt_price = tick_to_price(current_tick / 2)
adjusted_current_price = current_price / (10 ** (decimals1 - decimals0))
print("Current price={:.6g} {} for {} at tick {}".format(adjusted_current_price, token1, token0, current_tick))

# Sum up all the active liquidity and total amounts in the pool
active_positions_liquidity = 0
total_amount0 = 0
total_amount1 = 0

# Print all active positions
for tick_lower, tick_upper, liquidity, id in sorted(positions):

    sa = tick_to_price(tick_lower / 2)
    sb = tick_to_price(tick_upper / 2)

    if tick_upper < current_tick:
        # Only token1 locked
        amount1 = liquidity * (sb - sa) # eq(9) in technical note
        total_amount1 += amount1

    elif tick_lower <= current_tick <= tick_upper:
        # Both tokens present
        amount0 = liquidity * (sb - current_sqrt_price) / (current_sqrt_price * sb) # eq(12) in technical note
        amount1 = liquidity * (current_sqrt_price - sa) # eq(13) in technical note
        adjusted_amount0 = amount0 / (10 ** decimals0)
        adjusted_amount1 = amount1 / (10 ** decimals1)

        total_amount0 += amount0
        total_amount1 += amount1
        active_positions_liquidity += liquidity

        print("  position {: 7g} in range [{},{}]: {:.6g} {} and {:.6g} {} at the current price".format(
              id, tick_lower, tick_upper,
              adjusted_amount0, token0, adjusted_amount1, token1))
    else:
        # Only token0 locked
        amount0 = liquidity * (sb - sa) / (sa * sb) # eq(4) in technical note
        total_amount0 += amount0


print("In total (including inactive positions): {:.6g} {} and {:.6g} {}".format(
      total_amount0 / 10 ** decimals0, token0, total_amount1 / 10 ** decimals1, token1))
print("Total liquidity from active positions: {}, from pool: {} (should be equal...)".format(
      active_positions_liquidity, pool_liquidity))
# Out:
# Current price=0.000303297 WETH for USDC at tick 195312
#   position  104211 in range [-887220,887220]: 1.13261 USDC and 0.000343517 WETH at the current price
#   position  127449 in range [-887220,887220]: 4.79148 USDC and 0.00145324 WETH at the current price
#   position  104069 in range [-887220,887220]: 5.75536 USDC and 0.00174558 WETH at the current price
#   position  114656 in range [-887220,887220]: 7.9392 USDC and 0.00240794 WETH at the current price
#   position  110416 in range [-887220,887220]: 252.6 USDC and 0.076613 WETH at the current price
#   position  128009 in range [-887220,887220]: 339.887 USDC and 0.103087 WETH at the current price
#   position  106613 in range [-887220,887220]: 443.445 USDC and 0.134496 WETH at the current price
#   position  119305 in range [-887220,887220]: 1015.94 USDC and 0.308133 WETH at the current price
#   position  127637 in range [-887220,887220]: 1021.31 USDC and 0.309759 WETH at the current price
#   position  116530 in range [-887220,887220]: 3475.65 USDC and 1.05416 WETH at the current price
#   position  133339 in range [-887220,887220]: 9323.66 USDC and 2.82784 WETH at the current price
#   position  126131 in range [-887220,887220]: 60648.4 USDC and 18.3945 WETH at the current price
#   position  111115 in range [-887220,887220]: 126077 USDC and 38.2387 WETH at the current price
#   position   37340 in range [-300240,203160]: 448.592 USDC and 0.419213 WETH at the current price
#   position   13265 in range [-1080,414480]: 54850.2 USDC and 16.6353 WETH at the current price
#   position    8156 in range [46080,276300]: 314.912 USDC and 0.0971508 WETH at the current price
#   position   16493 in range [46080,483540]: 25210.4 USDC and 7.64184 WETH at the current price
#   position   55494 in range [62460,246720]: 23.2662 USDC and 0.00763126 WETH at the current price
#   position   74350 in range [63780,253320]: 159.327 USDC and 0.0510651 WETH at the current price
#   position   51577 in range [69060,199140]: 899.024 USDC and 1.56253 WETH at the current price
#   position   77374 in range [69060,299340]: 132.913 USDC and 0.0404621 WETH at the current price
#   position   48615 in range [69060,598680]: 563.202 USDC and 0.170508 WETH at the current price
#   position   19287 in range [92040,276360]: 2787.53 USDC and 0.855483 WETH at the current price
#   position   13577 in range [92100,368460]: 111.166 USDC and 0.0335287 WETH at the current price
#   position   47234 in range [115140,322380]: 2900.54 USDC and 0.865253 WETH at the current price
#   position  102091 in range [121860,276300]: 2925.52 USDC and 0.880096 WETH at the current price
#   position   20440 in range [127020,200040]: 285.285 USDC and 0.39748 WETH at the current price
#   position   10023 in range [138180,207240]: 10.2 USDC and 0.0064913 WETH at the current price
#   position   88352 in range [138180,210840]: 1414.34 USDC and 0.748835 WETH at the current price
#   position    9998 in range [138180,230280]: 2.99745 USDC and 0.00103746 WETH at the current price
#   position   12263 in range [138180,251460]: 569700 USDC and 173.321 WETH at the current price
#   position   79891 in range [138180,253320]: 140.719 USDC and 0.0425684 WETH at the current price
#   position   13127 in range [138180,276300]: 5381.62 USDC and 1.56572 WETH at the current price
#   position   56737 in range [145080,276300]: 66.4404 USDC and 0.0188445 WETH at the current price
#   position   39191 in range [149160,241260]: 19.0303 USDC and 0.00577839 WETH at the current price
#   position  119077 in range [149160,241260]: 3480.25 USDC and 1.05675 WETH at the current price
#   position   35480 in range [150180,197460]: 19.9715 USDC and 0.053256 WETH at the current price
#   position   27504 in range [152340,244440]: 2906.66 USDC and 0.85178 WETH at the current price
#   position   79083 in range [153600,245760]: 2259.55 USDC and 0.652553 WETH at the current price
#   position   34355 in range [154380,241920]: 16348.1 USDC and 4.78303 WETH at the current price
#   position   67753 in range [156060,328860]: 118.96 USDC and 0.0310497 WETH at the current price
#   position  132038 in range [157080,230220]: 508.896 USDC and 0.159345 WETH at the current price
#   position   47091 in range [157140,230280]: 781.827 USDC and 0.244523 WETH at the current price
#   position   21421 in range [160560,209520]: 7527.11 USDC and 3.69935 WETH at the current price
#   position   33858 in range [161160,196980]: 10195.2 USDC and 31.6389 WETH at the current price
#   position   10201 in range [161160,214200]: 687.814 USDC and 0.27949 WETH at the current price
#   position    8236 in range [161160,214200]: 790.494 USDC and 0.321213 WETH at the current price
#   position    3763 in range [161160,229260]: 2.44083 USDC and 0.00074198 WETH at the current price
#   position   18608 in range [161160,230220]: 567.891 USDC and 0.170836 WETH at the current price
#   position   62400 in range [161160,230280]: 0.0141824 USDC and 4.26373e-06 WETH at the current price
#   position   62399 in range [161160,230280]: 0.014183 USDC and 4.2639e-06 WETH at the current price
#   position   62436 in range [161160,230280]: 0.0141866 USDC and 4.265e-06 WETH at the current price
#   position   62349 in range [161160,230280]: 0.0142095 USDC and 4.27187e-06 WETH at the current price
#   position   62443 in range [161160,230280]: 0.0142162 USDC and 4.2739e-06 WETH at the current price
#   position   62387 in range [161160,230280]: 0.0142254 USDC and 4.27666e-06 WETH at the current price
#   position   62367 in range [161160,230280]: 0.0142256 USDC and 4.27672e-06 WETH at the current price
#   position   62330 in range [161160,230280]: 0.01423 USDC and 4.27805e-06 WETH at the current price
#   position   62471 in range [161160,230280]: 0.0142305 USDC and 4.27818e-06 WETH at the current price
#   position   62452 in range [161160,230280]: 0.0142383 USDC and 4.28052e-06 WETH at the current price
#   position   62465 in range [161160,230280]: 0.0142429 USDC and 4.28192e-06 WETH at the current price
#   position   62315 in range [161160,230280]: 0.0142548 USDC and 4.2855e-06 WETH at the current price
#   position   62477 in range [161160,230280]: 0.014298 USDC and 4.29847e-06 WETH at the current price
#   position   62510 in range [161160,230280]: 0.0143169 USDC and 4.30417e-06 WETH at the current price
#   position   62492 in range [161160,230280]: 0.0143199 USDC and 4.30507e-06 WETH at the current price
#   position   61112 in range [161160,230280]: 0.0143922 USDC and 4.32681e-06 WETH at the current price
#   position   61117 in range [161160,230280]: 0.0144188 USDC and 4.3348e-06 WETH at the current price
#   position   61163 in range [161160,230280]: 0.0144316 USDC and 4.33865e-06 WETH at the current price
#   position   61185 in range [161160,230280]: 0.0144316 USDC and 4.33865e-06 WETH at the current price
#   position   61125 in range [161160,230280]: 0.0144419 USDC and 4.34174e-06 WETH at the current price
#   position   61150 in range [161160,230280]: 0.0144452 USDC and 4.34274e-06 WETH at the current price
#   position   61129 in range [161160,230280]: 0.0144484 USDC and 4.3437e-06 WETH at the current price
#   position   61094 in range [161160,230280]: 0.0144585 USDC and 4.34673e-06 WETH at the current price
#   position   61080 in range [161160,230280]: 0.0144935 USDC and 4.35726e-06 WETH at the current price
#   position   61494 in range [161160,230280]: 0.0146954 USDC and 4.41795e-06 WETH at the current price
#   position   62539 in range [161160,230280]: 0.0285876 USDC and 8.59443e-06 WETH at the current price
#   position   70055 in range [161160,230280]: 0.130427 USDC and 3.9211e-05 WETH at the current price
#   position   69994 in range [161160,230280]: 0.130492 USDC and 3.92305e-05 WETH at the current price
#   position   70009 in range [161160,230280]: 0.130492 USDC and 3.92305e-05 WETH at the current price
#   position   69969 in range [161160,230280]: 0.130548 USDC and 3.92474e-05 WETH at the current price
#   position   69978 in range [161160,230280]: 0.130548 USDC and 3.92474e-05 WETH at the current price
#   position   69842 in range [161160,230280]: 0.130945 USDC and 3.93668e-05 WETH at the current price
#   position   69915 in range [161160,230280]: 0.131012 USDC and 3.93869e-05 WETH at the current price
#   position   69897 in range [161160,230280]: 0.131019 USDC and 3.93891e-05 WETH at the current price
#   position   69907 in range [161160,230280]: 0.131019 USDC and 3.93891e-05 WETH at the current price
#   position   69871 in range [161160,230280]: 0.131019 USDC and 3.93891e-05 WETH at the current price
#   position   61140 in range [161160,230280]: 0.144484 USDC and 4.3437e-05 WETH at the current price
#   position   61074 in range [161160,230280]: 0.145073 USDC and 4.3614e-05 WETH at the current price
#   position    9997 in range [161160,230280]: 3.47055 USDC and 0.00104337 WETH at the current price
#   position   69940 in range [161160,230280]: 6.54328 USDC and 0.00196714 WETH at the current price
#   position   51256 in range [161160,230280]: 27.0866 USDC and 0.00814319 WETH at the current price
#   position    6832 in range [161160,230280]: 33.4595 USDC and 0.0100591 WETH at the current price
#   position   79528 in range [161160,230280]: 36.8757 USDC and 0.0110861 WETH at the current price
#   position    7921 in range [161160,230280]: 252.973 USDC and 0.0760527 WETH at the current price
#   position     827 in range [161160,230280]: 4469.69 USDC and 1.34375 WETH at the current price
#   position   72285 in range [161160,276300]: 294.257 USDC and 0.0743619 WETH at the current price
#   position    4343 in range [161160,276300]: 1741.32 USDC and 0.44005 WETH at the current price
#   position   23886 in range [161160,276300]: 7532.59 USDC and 1.90357 WETH at the current price
#   position    5206 in range [161160,299340]: 121.445 USDC and 0.0303224 WETH at the current price
#   position   47000 in range [161160,345420]: 600.932 USDC and 0.149296 WETH at the current price
#   position   18586 in range [163380,209460]: 84831.4 USDC and 40.4616 WETH at the current price
#   position   26642 in range [164760,210780]: 4378.21 USDC and 1.93049 WETH at the current price
#   position  111040 in range [167940,196740]: 15436.1 USDC and 50.6523 WETH at the current price
#   position   76628 in range [168120,223320]: 782.59 USDC and 0.234124 WETH at the current price
#   position    5125 in range [169200,207240]: 50.489 USDC and 0.024851 WETH at the current price
#   position  111378 in range [169260,241620]: 548.907 USDC and 0.134506 WETH at the current price
#   position   61361 in range [170340,201720]: 0.331459 USDC and 0.000261503 WETH at the current price
#   position    2303 in range [170340,207240]: 5381.17 USDC and 2.59089 WETH at the current price
#   position  100207 in range [170340,211500]: 28474.9 USDC and 11.099 WETH at the current price
#   position   37542 in range [171420,223320]: 944.387 USDC and 0.265017 WETH at the current price
#   position   13123 in range [171720,207240]: 36742.3 USDC and 17.182 WETH at the current price
#   position   11893 in range [171780,214200]: 3387.84 USDC and 1.16303 WETH at the current price
#   position    6622 in range [172200,218220]: 838.282 USDC and 0.255452 WETH at the current price
#   position   20233 in range [172440,230280]: 1154.43 USDC and 0.288826 WETH at the current price
#   position   10547 in range [172740,216420]: 44081.1 USDC and 13.8735 WETH at the current price
#   position   11370 in range [173220,196260]: 30879.8 USDC and 135.279 WETH at the current price
#   position    6135 in range [173220,203160]: 921.927 USDC and 0.576064 WETH at the current price
#   position    5601 in range [173220,207240]: 2493.75 USDC and 1.12585 WETH at the current price
#   position   14700 in range [173700,214200]: 595.666 USDC and 0.195305 WETH at the current price
#   position   28048 in range [174660,214200]: 679.181 USDC and 0.217062 WETH at the current price
#   position  110430 in range [174960,231540]: 3061.12 USDC and 0.708641 WETH at the current price
#   position  130832 in range [175080,195960]: 785.245 USDC and 4.754 WETH at the current price
#   position   28344 in range [175080,198060]: 0.0540127 USDC and 8.12054e-05 WETH at the current price
#   position   28349 in range [175080,198060]: 0.0540127 USDC and 8.12054e-05 WETH at the current price
#   position   28746 in range [175080,198060]: 0.0540127 USDC and 8.12054e-05 WETH at the current price
#   position   28751 in range [175080,198060]: 0.0540127 USDC and 8.12054e-05 WETH at the current price
#   position   28338 in range [175080,198060]: 0.540127 USDC and 0.000812054 WETH at the current price
#   position   28339 in range [175080,198060]: 0.540127 USDC and 0.000812054 WETH at the current price
#   position   28352 in range [175080,198060]: 0.540127 USDC and 0.000812054 WETH at the current price
#   position   28356 in range [175080,198060]: 0.540127 USDC and 0.000812054 WETH at the current price
#   position   28733 in range [175080,198060]: 0.540127 USDC and 0.000812054 WETH at the current price
#   position   46590 in range [175080,207240]: 693.745 USDC and 0.298077 WETH at the current price
#   position   80154 in range [175080,230280]: 4425.26 USDC and 1.03408 WETH at the current price
#   position   42560 in range [176160,207240]: 191.886 USDC and 0.0798321 WETH at the current price
#   position   16740 in range [176160,213420]: 87320.1 USDC and 27.3985 WETH at the current price
#   position   49814 in range [176340,219300]: 1814.72 USDC and 0.482716 WETH at the current price
#   position   40136 in range [176700,219240]: 924.791 USDC and 0.243486 WETH at the current price
#   position   22600 in range [176940,220680]: 6289.28 USDC and 1.59487 WETH at the current price
#   position   20835 in range [177180,212340]: 2.07368e+06 USDC and 654.093 WETH at the current price
#   position  124439 in range [177240,223380]: 542347 USDC and 129.739 WETH at the current price
#   position   26794 in range [177300,203160]: 131.486 USDC and 0.0729453 WETH at the current price
#   position   71182 in range [177300,207240]: 0.167768 USDC and 6.7248e-05 WETH at the current price
#   position   30284 in range [177300,207240]: 32997.4 USDC and 13.2267 WETH at the current price
#   position   71612 in range [177300,214200]: 0.136019 USDC and 4.00786e-05 WETH at the current price
#   position   71343 in range [177300,214200]: 0.141047 USDC and 4.15601e-05 WETH at the current price
#   position   71281 in range [177300,214200]: 0.141824 USDC and 4.17889e-05 WETH at the current price
#   position   71278 in range [177300,214200]: 0.141869 USDC and 4.18023e-05 WETH at the current price
#   position   71270 in range [177300,214200]: 0.142059 USDC and 4.18583e-05 WETH at the current price
#   position   71248 in range [177300,214200]: 0.14206 USDC and 4.18586e-05 WETH at the current price
#   position   71234 in range [177300,214200]: 0.14206 USDC and 4.18586e-05 WETH at the current price
#   position   71219 in range [177300,214200]: 0.142088 USDC and 4.18669e-05 WETH at the current price
#   position   71203 in range [177300,214200]: 0.142105 USDC and 4.18719e-05 WETH at the current price
#   position   71211 in range [177300,214200]: 0.142105 USDC and 4.18719e-05 WETH at the current price
#   position    8011 in range [177300,214200]: 6253.7 USDC and 1.84268 WETH at the current price
#   position   24693 in range [177300,221100]: 28.4586 USDC and 0.00707214 WETH at the current price
#   position   78389 in range [177300,222240]: 299399 USDC and 72.8677 WETH at the current price
#   position   90218 in range [177300,225840]: 130.928 USDC and 0.0301202 WETH at the current price
#   position   77771 in range [177300,260220]: 24.3616 USDC and 0.00456423 WETH at the current price
#   position   78599 in range [177300,276300]: 337.557 USDC and 0.0618572 WETH at the current price
#   position  133100 in range [177840,196320]: 53656.1 USDC and 192.885 WETH at the current price
#   position  122158 in range [177840,200640]: 14449.9 USDC and 10.917 WETH at the current price
#   position   18440 in range [178320,201360]: 240.328 USDC and 0.159889 WETH at the current price
#   position   40123 in range [178740,217740]: 307.882 USDC and 0.0780274 WETH at the current price
#   position  118804 in range [178860,210780]: 19424.7 USDC and 6.13382 WETH at the current price
#   position  127126 in range [179280,196740]: 427.101 USDC and 1.03652 WETH at the current price
#   position    9166 in range [179820,210120]: 3341.51 USDC and 1.04454 WETH at the current price
#   position   49435 in range [180060,207240]: 32548.4 USDC and 11.7253 WETH at the current price
#   position   39501 in range [180120,214440]: 3056.47 USDC and 0.80118 WETH at the current price
#   position   27916 in range [180180,203880]: 1228.89 USDC and 0.567713 WETH at the current price
#   position   42750 in range [180180,207240]: 330.912 USDC and 0.118581 WETH at the current price
#   position  133286 in range [180180,207240]: 37316.8 USDC and 13.3724 WETH at the current price
#   position   21693 in range [180180,212340]: 27.0235 USDC and 0.00758923 WETH at the current price
#   position   15211 in range [180180,214200]: 13969.8 USDC and 3.67989 WETH at the current price
#   position   11979 in range [180840,214200]: 10128.2 USDC and 2.5888 WETH at the current price
#   position   68764 in range [180960,215280]: 2994.21 USDC and 0.736359 WETH at the current price
#   position   14997 in range [181020,205620]: 158.274 USDC and 0.0608623 WETH at the current price
#   position   79647 in range [181140,276360]: 224.778 USDC and 0.0352211 WETH at the current price
#   position   39779 in range [181260,214200]: 316.542 USDC and 0.0792925 WETH at the current price
#   position  123837 in range [181320,204900]: 9509.27 USDC and 3.81086 WETH at the current price
#   position   22656 in range [181380,214200]: 77334.7 USDC and 19.2576 WETH at the current price
#   position   13057 in range [181440,206760]: 20006.3 USDC and 6.96444 WETH at the current price
#   position   14408 in range [181620,205560]: 15948 USDC and 5.98025 WETH at the current price
#   position   26338 in range [181620,219300]: 3700.61 USDC and 0.796378 WETH at the current price
#   position   44601 in range [181800,206340]: 162.606 USDC and 0.0571478 WETH at the current price
#   position   13640 in range [181980,211020]: 129686 USDC and 35.1753 WETH at the current price
#   position   29921 in range [182100,202500]: 21950.9 USDC and 10.6613 WETH at the current price
#   position    5968 in range [182100,207240]: 991.235 USDC and 0.323561 WETH at the current price
#   position    6584 in range [182340,210120]: 377.784 USDC and 0.104536 WETH at the current price
#   position  130417 in range [182400,199680]: 466022 USDC and 342.671 WETH at the current price
#   position   33531 in range [182400,208860]: 15546.4 USDC and 4.55792 WETH at the current price
#   position   43221 in range [182580,200400]: 680.122 USDC and 0.432467 WETH at the current price
#   position   13401 in range [182700,205500]: 24484.8 USDC and 8.70221 WETH at the current price
#   position    7193 in range [183180,276300]: 0.97583 USDC and 0.000136989 WETH at the current price
#   position    4637 in range [183720,205740]: 32638.4 USDC and 10.7169 WETH at the current price
#   position   14745 in range [183960,204240]: 1551.38 USDC and 0.56598 WETH at the current price
#   position  104489 in range [184020,202620]: 4572.9 USDC and 1.95487 WETH at the current price
#   position   13006 in range [184140,201660]: 1340.81 USDC and 0.639978 WETH at the current price
#   position   23496 in range [184200,196920]: 3.61089 USDC and 0.0060431 WETH at the current price
#   position   38439 in range [184200,197280]: 2329.27 USDC and 3.21349 WETH at the current price
#   position   44149 in range [184200,198480]: 10905.4 USDC and 9.62474 WETH at the current price
#   position   22673 in range [184200,200340]: 42.7945 USDC and 0.0248902 WETH at the current price
#   position     311 in range [184200,200340]: 764.431 USDC and 0.44461 WETH at the current price
#   position  110645 in range [184200,200340]: 10101.2 USDC and 5.87506 WETH at the current price
#   position   15060 in range [184200,200340]: 16289.8 USDC and 9.47453 WETH at the current price
#   position   36533 in range [184200,201360]: 167.918 USDC and 0.0831925 WETH at the current price
#   position   23987 in range [184200,201360]: 371.005 USDC and 0.183809 WETH at the current price
#   position  125706 in range [184200,201840]: 4.64565 USDC and 0.00215677 WETH at the current price
#   position  129763 in range [184200,203100]: 105099 USDC and 42.1284 WETH at the current price
#   position   33332 in range [184200,203160]: 144.321 USDC and 0.0574889 WETH at the current price
#   position   39510 in range [184200,203160]: 2856.37 USDC and 1.13781 WETH at the current price
#   position  104329 in range [184200,203160]: 95341.9 USDC and 37.9784 WETH at the current price
#   position   15362 in range [184200,204000]: 22037.3 USDC and 8.08618 WETH at the current price
#   position   68343 in range [184200,205440]: 6925.19 USDC and 2.25334 WETH at the current price
#   position   48410 in range [184200,205440]: 13805.9 USDC and 4.4922 WETH at the current price
#   position   95805 in range [184200,206400]: 0.178667 USDC and 5.42769e-05 WETH at the current price
#   position   95817 in range [184200,206400]: 0.17962 USDC and 5.45663e-05 WETH at the current price
#   position   95828 in range [184200,206460]: 0.179486 USDC and 5.43062e-05 WETH at the current price
#   position   95629 in range [184200,206460]: 0.179491 USDC and 5.43076e-05 WETH at the current price
#   position   95837 in range [184200,206460]: 0.17957 USDC and 5.43316e-05 WETH at the current price
#   position   95848 in range [184200,206460]: 0.17957 USDC and 5.43316e-05 WETH at the current price
#   position   95878 in range [184200,206460]: 0.180203 USDC and 5.45231e-05 WETH at the current price
#   position   95621 in range [184200,206520]: 0.180653 USDC and 5.44407e-05 WETH at the current price
#   position  115138 in range [184200,206640]: 5196.97 USDC and 1.55376 WETH at the current price
#   position   95793 in range [184200,207240]: 0.171676 USDC and 4.94102e-05 WETH at the current price
#   position   95794 in range [184200,207240]: 0.171676 USDC and 4.94102e-05 WETH at the current price
#   position   95834 in range [184200,207240]: 0.172863 USDC and 4.97517e-05 WETH at the current price
#   position   78942 in range [184200,207240]: 0.178954 USDC and 5.15049e-05 WETH at the current price
#   position   78953 in range [184200,207240]: 0.178954 USDC and 5.15049e-05 WETH at the current price
#   position   78939 in range [184200,207240]: 0.178955 USDC and 5.1505e-05 WETH at the current price
#   position   78864 in range [184200,207240]: 0.17904 USDC and 5.15294e-05 WETH at the current price
#   position   78869 in range [184200,207240]: 0.17904 USDC and 5.15294e-05 WETH at the current price
#   position   78862 in range [184200,207240]: 0.17904 USDC and 5.15294e-05 WETH at the current price
#   position   78842 in range [184200,207240]: 0.179043 USDC and 5.15304e-05 WETH at the current price
#   position   78799 in range [184200,207240]: 0.179872 USDC and 5.17689e-05 WETH at the current price
#   position   78812 in range [184200,207240]: 0.179872 USDC and 5.17689e-05 WETH at the current price
#   position   78787 in range [184200,207240]: 0.179872 USDC and 5.17689e-05 WETH at the current price
#   position   78659 in range [184200,207240]: 0.181368 USDC and 5.21995e-05 WETH at the current price
#   position   78666 in range [184200,207240]: 0.181528 USDC and 5.22456e-05 WETH at the current price
#   position   78677 in range [184200,207240]: 0.182141 USDC and 5.24221e-05 WETH at the current price
#   position   78695 in range [184200,207240]: 0.182141 USDC and 5.24221e-05 WETH at the current price
#   position   78700 in range [184200,207240]: 0.182141 USDC and 5.24221e-05 WETH at the current price
#   position   78727 in range [184200,207240]: 0.182387 USDC and 5.24928e-05 WETH at the current price
#   position   78605 in range [184200,207240]: 0.182572 USDC and 5.25462e-05 WETH at the current price
#   position   78619 in range [184200,207240]: 0.182572 USDC and 5.25462e-05 WETH at the current price
#   position   78553 in range [184200,207240]: 0.182689 USDC and 5.25796e-05 WETH at the current price
#   position   78578 in range [184200,207240]: 0.183256 USDC and 5.27429e-05 WETH at the current price
#   position   87796 in range [184200,207240]: 0.2664 USDC and 7.66728e-05 WETH at the current price
#   position   45813 in range [184200,207240]: 152.196 USDC and 0.0438037 WETH at the current price
#   position    8554 in range [184200,207240]: 209.112 USDC and 0.0601845 WETH at the current price
#   position   55883 in range [184200,207240]: 702.433 USDC and 0.202167 WETH at the current price
#   position   34565 in range [184200,207240]: 1157.34 USDC and 0.333094 WETH at the current price
#   position    2154 in range [184200,207240]: 1229.23 USDC and 0.353785 WETH at the current price
#   position   22277 in range [184200,207240]: 1347.49 USDC and 0.387821 WETH at the current price
#   position   26852 in range [184200,207240]: 2472.62 USDC and 0.711646 WETH at the current price
#   position   31662 in range [184200,207240]: 2684.37 USDC and 0.77259 WETH at the current price
#   position    3270 in range [184200,207240]: 2719 USDC and 0.782557 WETH at the current price
#   position   24561 in range [184200,207240]: 2880.47 USDC and 0.829029 WETH at the current price
#   position   19136 in range [184200,207240]: 3087.72 USDC and 0.888678 WETH at the current price
#   position    1972 in range [184200,207240]: 4360.28 USDC and 1.25493 WETH at the current price
#   position   37956 in range [184200,207240]: 6574.9 USDC and 1.89232 WETH at the current price
#   position    1526 in range [184200,207240]: 26215.4 USDC and 7.54505 WETH at the current price
#   position    1897 in range [184200,207240]: 53463.7 USDC and 15.3874 WETH at the current price
#   position   12148 in range [184200,207240]: 78606.2 USDC and 22.6237 WETH at the current price
#   position   11138 in range [184200,207240]: 82279 USDC and 23.6807 WETH at the current price
#   position   37946 in range [184200,207240]: 122500 USDC and 35.2568 WETH at the current price
#   position   67196 in range [184200,207240]: 174867 USDC and 50.3284 WETH at the current price
#   position   22967 in range [184200,207240]: 200609 USDC and 57.7374 WETH at the current price
#   position   87789 in range [184200,207420]: 0.201641 USDC and 5.74037e-05 WETH at the current price
#   position   39094 in range [184200,209460]: 136.92 USDC and 0.0349098 WETH at the current price
#   position   27608 in range [184200,210120]: 14553 USDC and 3.597 WETH at the current price
#   position   29528 in range [184200,210120]: 23685.3 USDC and 5.85418 WETH at the current price
#   position   35819 in range [184200,210480]: 7904.45 USDC and 1.92244 WETH at the current price
#   position   63444 in range [184200,212340]: 82.548 USDC and 0.0186194 WETH at the current price
#   position   41272 in range [184200,212340]: 749.738 USDC and 0.16911 WETH at the current price
#   position   21538 in range [184200,214140]: 68607.6 USDC and 14.5429 WETH at the current price
#   position   30060 in range [184200,214200]: 884.959 USDC and 0.187228 WETH at the current price
#   position   36352 in range [184200,216420]: 651.574 USDC and 0.129212 WETH at the current price
#   position   23917 in range [184200,219300]: 7583.57 USDC and 1.40339 WETH at the current price
#   position   45113 in range [184200,223320]: 51220.5 USDC and 8.78838 WETH at the current price
#   position   77770 in range [184200,230280]: 0.0131898 USDC and 2.06458e-06 WETH at the current price
#   position   69883 in range [184200,230280]: 0.131019 USDC and 2.05083e-05 WETH at the current price
#   position    1650 in range [184200,230280]: 97.4053 USDC and 0.0152467 WETH at the current price
#   position   35440 in range [184200,230280]: 1234.34 USDC and 0.19321 WETH at the current price
#   position   44978 in range [184200,237180]: 4072.97 USDC and 0.600605 WETH at the current price
#   position   64752 in range [184200,244980]: 64.015 USDC and 0.0090297 WETH at the current price
#   position    7091 in range [184200,276300]: 0.577878 USDC and 7.60352e-05 WETH at the current price
#   position    7073 in range [184200,276300]: 0.979473 USDC and 0.000128876 WETH at the current price
#   position    7067 in range [184200,276300]: 0.979473 USDC and 0.000128876 WETH at the current price
#   position    7062 in range [184200,276300]: 0.979539 USDC and 0.000128884 WETH at the current price
#   position   10141 in range [184200,276300]: 1.93153 USDC and 0.000254144 WETH at the current price
#   position   42256 in range [184200,276300]: 11.4171 USDC and 0.00150222 WETH at the current price
#   position    3686 in range [184200,276420]: 0.978337 USDC and 0.000128712 WETH at the current price
#   position    9838 in range [184200,276420]: 3.89343 USDC and 0.00051223 WETH at the current price
#   position   57628 in range [184200,299340]: 557.59 USDC and 0.0724859 WETH at the current price
#   position   22991 in range [184200,391440]: 1139.58 USDC and 0.147336 WETH at the current price
#   position    6669 in range [184260,202500]: 2749.24 USDC and 1.17257 WETH at the current price
#   position   55588 in range [184320,216780]: 1536.76 USDC and 0.299431 WETH at the current price
#   position    4984 in range [184500,204480]: 35449.8 USDC and 12.2108 WETH at the current price
#   position    6901 in range [184560,212340]: 570.889 USDC and 0.125621 WETH at the current price
#   position    9473 in range [184620,230280]: 24.2883 USDC and 0.00369322 WETH at the current price
#   position   16069 in range [184740,197100]: 35.3104 USDC and 0.0514155 WETH at the current price
#   position   12984 in range [184740,203160]: 7239.2 USDC and 2.77744 WETH at the current price
#   position  128977 in range [184800,414480]: 192262 USDC and 23.8376 WETH at the current price
#   position   18577 in range [184860,209100]: 9063.05 USDC and 2.24607 WETH at the current price
#   position   24305 in range [184920,209640]: 711.301 USDC and 0.170921 WETH at the current price
#   position   19322 in range [185280,199800]: 8325.42 USDC and 4.95509 WETH at the current price
#   position   34976 in range [185280,207240]: 68.0525 USDC and 0.0181235 WETH at the current price
#   position   28952 in range [185280,207240]: 5234.47 USDC and 1.39403 WETH at the current price
#   position   25356 in range [185280,208320]: 11492.7 USDC and 2.87537 WETH at the current price
#   position   46200 in range [185280,209460]: 18871.3 USDC and 4.4522 WETH at the current price
#   position  118557 in range [185340,198240]: 203.51 USDC and 0.177947 WETH at the current price
#   position  114205 in range [185400,197340]: 768.853 USDC and 0.945058 WETH at the current price
#   position  130021 in range [185400,206880]: 23807.3 USDC and 6.42478 WETH at the current price
#   position  112509 in range [185580,196080]: 1361.07 USDC and 4.222 WETH at the current price
#   position  122400 in range [185580,201600]: 3867.42 USDC and 1.67524 WETH at the current price
#   position    4803 in range [185580,203880]: 2764 USDC and 0.926939 WETH at the current price
#   position  124883 in range [185760,197220]: 48158.9 USDC and 60.9573 WETH at the current price
#   position     436 in range [185820,197340]: 1552.18 USDC and 1.84479 WETH at the current price
#   position    2662 in range [185820,200340]: 19422.8 USDC and 10.0139 WETH at the current price
#   position   12782 in range [185820,200400]: 367217 USDC and 187.364 WETH at the current price
#   position   25808 in range [185820,204600]: 10186.4 USDC and 3.14254 WETH at the current price
#   position   85205 in range [185940,204780]: 16209.4 USDC and 4.87719 WETH at the current price
#   position   24080 in range [186000,207240]: 20603.8 USDC and 5.17834 WETH at the current price
#   position  132450 in range [186240,414480]: 39.3074 USDC and 0.00434736 WETH at the current price
#   position   18573 in range [186300,207300]: 4559.22 USDC and 1.11258 WETH at the current price
#   position   26830 in range [186360,201480]: 40774.1 USDC and 16.8152 WETH at the current price
#   position   24539 in range [186360,207420]: 29719 USDC and 7.1618 WETH at the current price
#   position   25956 in range [186420,196620]: 4893.93 USDC and 8.41537 WETH at the current price
#   position   28500 in range [186420,200280]: 15055.9 USDC and 7.45153 WETH at the current price
#   position   13490 in range [186420,200340]: 1013.72 USDC and 0.496441 WETH at the current price
#   position  109068 in range [186420,200340]: 47080.1 USDC and 23.0561 WETH at the current price
#   position   14828 in range [186420,200340]: 58219.8 USDC and 28.5115 WETH at the current price
#   position   14831 in range [186420,200340]: 118045 USDC and 57.8091 WETH at the current price
#   position  127808 in range [186420,200520]: 989.343 USDC and 0.469777 WETH at the current price
#   position   81606 in range [186420,200580]: 14801.2 USDC and 6.9581 WETH at the current price
#   position   73123 in range [186420,200820]: 51107.3 USDC and 23.1109 WETH at the current price
#   position   75696 in range [186420,200880]: 10460.9 USDC and 4.6862 WETH at the current price
#   position   62323 in range [186420,200940]: 2483.19 USDC and 1.10211 WETH at the current price
#   position    2695 in range [186420,203160]: 410.47 USDC and 0.137672 WETH at the current price
#   position  132315 in range [186420,203160]: 2470 USDC and 0.828437 WETH at the current price
#   position  128511 in range [186420,203160]: 3796.05 USDC and 1.27319 WETH at the current price
#   position    1730 in range [186420,203160]: 5038.4 USDC and 1.68988 WETH at the current price
#   position   51480 in range [186420,203160]: 44241.2 USDC and 14.8385 WETH at the current price
#   position  120437 in range [186420,204300]: 6568.64 USDC and 1.97535 WETH at the current price
#   position  111537 in range [186420,204600]: 27010.4 USDC and 7.91499 WETH at the current price
#   position   15698 in range [186420,205440]: 5808.23 USDC and 1.59128 WETH at the current price
#   position   38864 in range [186420,207240]: 1650.91 USDC and 0.400072 WETH at the current price
#   position   34694 in range [186420,207480]: 11826.2 USDC and 2.82458 WETH at the current price
#   position   63921 in range [186420,209460]: 845.16 USDC and 0.181438 WETH at the current price
#   position   66241 in range [186420,214200]: 1387.15 USDC and 0.247105 WETH at the current price
#   position   74807 in range [186420,262440]: 2.36654 USDC and 0.000266915 WETH at the current price
#   position  121638 in range [186480,200340]: 12.4826 USDC and 0.0060802 WETH at the current price
#   position  123121 in range [186540,200400]: 1496.31 USDC and 0.717381 WETH at the current price
#   position  121607 in range [186540,200400]: 2775.49 USDC and 1.33066 WETH at the current price
#   position  121875 in range [186600,200520]: 1401.16 USDC and 0.654578 WETH at the current price
#   position  121820 in range [186600,200520]: 4788.74 USDC and 2.23715 WETH at the current price
#   position  122039 in range [186660,198840]: 58302.5 USDC and 38.4 WETH at the current price
#   position  122411 in range [186660,200520]: 39176 USDC and 18.2011 WETH at the current price
#   position  121992 in range [186660,200580]: 19543.9 USDC and 8.98955 WETH at the current price
#   position   84966 in range [186660,201540]: 148489 USDC and 59.1073 WETH at the current price
#   position  112646 in range [186660,202500]: 3085.83 USDC and 1.08868 WETH at the current price
#   position   63591 in range [186660,209220]: 639.035 USDC and 0.135823 WETH at the current price
#   position  122376 in range [186780,200640]: 3397.84 USDC and 1.5303 WETH at the current price
#   position  122296 in range [186780,200640]: 9120.4 USDC and 4.1076 WETH at the current price
#   position  102247 in range [186780,414480]: 688.529 USDC and 0.0725195 WETH at the current price
#   position  128080 in range [186840,204960]: 17333.9 USDC and 4.74373 WETH at the current price
#   position  121252 in range [186960,200820]: 5831.72 USDC and 2.50821 WETH at the current price
#   position    6209 in range [187080,202560]: 398.958 USDC and 0.134303 WETH at the current price
#   position    3249 in range [187080,202920]: 65878.6 USDC and 21.3068 WETH at the current price
#   position   30704 in range [187080,207240]: 1643.41 USDC and 0.374389 WETH at the current price
#   position    6251 in range [187080,210120]: 3371.43 USDC and 0.659589 WETH at the current price
#   position    6678 in range [187080,210120]: 47422.6 USDC and 9.27779 WETH at the current price
#   position   30059 in range [187080,210540]: 1727.85 USDC and 0.331752 WETH at the current price
#   position  123406 in range [187140,201000]: 3957.83 USDC and 1.6266 WETH at the current price
#   position   85798 in range [187260,207240]: 60.5646 USDC and 0.0135524 WETH at the current price
#   position   38508 in range [187320,207300]: 11061.3 USDC and 2.45116 WETH at the current price
#   position  124696 in range [187500,203160]: 1441.63 USDC and 0.435602 WETH at the current price
#   position   18222 in range [187500,210780]: 10622.7 USDC and 1.93437 WETH at the current price
#   position  116884 in range [187620,201060]: 63800.9 USDC and 24.7338 WETH at the current price
#   position  127939 in range [187620,201480]: 42888.5 USDC and 15.6499 WETH at the current price
#   position  135078 in range [187620,202320]: 9398.96 USDC and 3.07908 WETH at the current price
#   position   63065 in range [187620,214800]: 278795 USDC and 43.3631 WETH at the current price
#   position  120306 in range [187680,201540]: 12192.4 USDC and 4.38413 WETH at the current price
#   position   28915 in range [187680,207240]: 3139.76 USDC and 0.672498 WETH at the current price
#   position  130833 in range [187740,195960]: 1509.76 USDC and 4.52701 WETH at the current price
#   position  106195 in range [187740,196260]: 3314.55 USDC and 6.84432 WETH at the current price
#   position     996 in range [187740,198060]: 4392.53 USDC and 3.27079 WETH at the current price
#   position  122834 in range [187740,199800]: 28231.8 USDC and 13.4265 WETH at the current price
#   position    5751 in range [187740,200160]: 12559.2 USDC and 5.57741 WETH at the current price
#   position   70661 in range [187740,201360]: 361.692 USDC and 0.132494 WETH at the current price
#   position  128651 in range [187740,201600]: 4.44844 USDC and 0.00157629 WETH at the current price
#   position  128706 in range [187740,201600]: 1561.01 USDC and 0.553141 WETH at the current price
#   position    9016 in range [187740,201660]: 3184.77 USDC and 1.11944 WETH at the current price
#   position  103942 in range [187740,208500]: 1059.92 USDC and 0.209843 WETH at the current price
#   position   26187 in range [187740,230220]: 121311 USDC and 14.0488 WETH at the current price
#   position   32776 in range [187800,199800]: 3865.27 USDC and 1.82624 WETH at the current price
#   position   32399 in range [187800,200280]: 293.995 USDC and 0.126939 WETH at the current price
#   position    8564 in range [187800,201660]: 9.01149 USDC and 0.00314684 WETH at the current price
#   position  128730 in range [187800,201660]: 315.824 USDC and 0.110287 WETH at the current price
#   position  128561 in range [187800,201660]: 630.497 USDC and 0.220172 WETH at the current price
#   position  124222 in range [187800,201660]: 1109.01 USDC and 0.387268 WETH at the current price
#   position    2457 in range [187800,202560]: 1597.79 USDC and 0.499154 WETH at the current price
#   position   88937 in range [187800,205620]: 3911.32 USDC and 0.922321 WETH at the current price
#   position   20837 in range [187800,208260]: 2.48944e+06 USDC and 496.058 WETH at the current price
#   position   35527 in range [187800,214200]: 18108.6 USDC and 2.81424 WETH at the current price
#   position  128269 in range [187860,201720]: 434.389 USDC and 0.149491 WETH at the current price
#   position   18870 in range [187860,206760]: 17194.2 USDC and 3.72197 WETH at the current price
#   position  120238 in range [187920,201780]: 190.759 USDC and 0.064698 WETH at the current price
#   position  128219 in range [187920,201780]: 1926.61 USDC and 0.653431 WETH at the current price
#   position  123512 in range [187920,201780]: 4579.56 USDC and 1.55321 WETH at the current price
#   position  128300 in range [187920,201780]: 65983 USDC and 22.3789 WETH at the current price
#   position  121426 in range [187980,199800]: 128185 USDC and 59.3629 WETH at the current price
#   position   15387 in range [187980,200880]: 5469.86 USDC and 2.09529 WETH at the current price
#   position  129129 in range [187980,201840]: 23.3259 USDC and 0.00779693 WETH at the current price
#   position  125750 in range [187980,201840]: 46.7625 USDC and 0.0156308 WETH at the current price
#   position  123870 in range [187980,201840]: 5343.75 USDC and 1.7862 WETH at the current price
#   position  128935 in range [187980,201900]: 449.339 USDC and 0.149039 WETH at the current price
#   position  126919 in range [187980,201900]: 9871.02 USDC and 3.27408 WETH at the current price
#   position  129123 in range [187980,202020]: 28.0337 USDC and 0.00915796 WETH at the current price
#   position   93931 in range [187980,202140]: 28.5325 USDC and 0.00918307 WETH at the current price
#   position  120807 in range [188040,197760]: 393.101 USDC and 0.315471 WETH at the current price
#   position  128449 in range [188040,201900]: 133.126 USDC and 0.0438564 WETH at the current price
#   position  127021 in range [188040,201900]: 64098.9 USDC and 21.1165 WETH at the current price
#   position  132902 in range [188100,200340]: 4168.11 USDC and 1.72173 WETH at the current price
#   position  126892 in range [188100,201960]: 4281.65 USDC and 1.39019 WETH at the current price
#   position  105179 in range [188100,203880]: 1.31774e+06 USDC and 347.241 WETH at the current price
#   position  129263 in range [188160,200340]: 63.1436 USDC and 0.0259023 WETH at the current price
#   position  126816 in range [188160,201960]: 4.76601 USDC and 0.00153674 WETH at the current price
#   position  128363 in range [188160,201960]: 419.799 USDC and 0.135359 WETH at the current price
#   position  123919 in range [188160,202020]: 64.2359 USDC and 0.020556 WETH at the current price
#   position  126728 in range [188160,202020]: 323.081 USDC and 0.103388 WETH at the current price
#   position  126791 in range [188160,202020]: 95550.2 USDC and 30.5768 WETH at the current price
#   position  110381 in range [188160,202380]: 1552.3 USDC and 0.475463 WETH at the current price
#   position  108810 in range [188220,195780]: 21299.1 USDC and 83.3871 WETH at the current price
#   position  126665 in range [188220,196620]: 421.262 USDC and 0.602534 WETH at the current price
#   position  126669 in range [188220,202080]: 291.146 USDC and 0.0918273 WETH at the current price
#   position  125622 in range [188280,196380]: 23.4641 USDC and 0.0405707 WETH at the current price
#   position  116064 in range [188280,200340]: 1047.22 USDC and 0.423567 WETH at the current price
#   position  124954 in range [188280,201360]: 3064.04 USDC and 1.05567 WETH at the current price
#   position  116522 in range [188280,202140]: 32.716 USDC and 0.0101701 WETH at the current price
#   position  125638 in range [188280,202140]: 98.0442 USDC and 0.0304781 WETH at the current price
#   position  117083 in range [188280,202140]: 116.476 USDC and 0.0362077 WETH at the current price
#   position  116578 in range [188280,202140]: 147.892 USDC and 0.0459737 WETH at the current price
#   position  125399 in range [188280,202140]: 333.931 USDC and 0.103806 WETH at the current price
#   position  116394 in range [188280,202140]: 343.669 USDC and 0.106833 WETH at the current price
#   position  126592 in range [188280,202140]: 361.488 USDC and 0.112373 WETH at the current price
#   position  116484 in range [188280,202140]: 958.896 USDC and 0.298084 WETH at the current price
#   position  125940 in range [188280,202140]: 4899.9 USDC and 1.52319 WETH at the current price
#   position  116568 in range [188280,202140]: 4922.7 USDC and 1.53028 WETH at the current price
#   position  116982 in range [188280,202140]: 16646.7 USDC and 5.17481 WETH at the current price
#   position  116497 in range [188280,202140]: 295471 USDC and 91.8505 WETH at the current price
#   position  114723 in range [188280,208140]: 4406.73 USDC and 0.836849 WETH at the current price
#   position  121261 in range [188340,199320]: 699.221 USDC and 0.343718 WETH at the current price
#   position  125280 in range [188340,202200]: 4.98349 USDC and 0.00152689 WETH at the current price
#   position  117110 in range [188340,202200]: 36.1496 USDC and 0.0110758 WETH at the current price
#   position  110788 in range [188340,202200]: 655.509 USDC and 0.200841 WETH at the current price
#   position  126527 in range [188340,202200]: 791.574 USDC and 0.24253 WETH at the current price
#   position  110673 in range [188340,202200]: 987.771 USDC and 0.302642 WETH at the current price
#   position  111784 in range [188340,202200]: 1140.63 USDC and 0.349475 WETH at the current price
#   position  110867 in range [188340,202200]: 1585.28 USDC and 0.485713 WETH at the current price
#   position  117151 in range [188340,202200]: 2439.73 USDC and 0.747507 WETH at the current price
#   position  129360 in range [188340,202200]: 20022.5 USDC and 6.13467 WETH at the current price
#   position  124874 in range [188340,202200]: 72402.4 USDC and 22.1833 WETH at the current price
#   position   35322 in range [188340,209340]: 115.281 USDC and 0.0204139 WETH at the current price
#   position   35144 in range [188340,209340]: 216.732 USDC and 0.0383787 WETH at the current price
#   position  125382 in range [188400,202260]: 15.0116 USDC and 0.00453323 WETH at the current price
#   position  125461 in range [188400,202260]: 145.45 USDC and 0.0439234 WETH at the current price
#   position  126422 in range [188400,202260]: 200.409 USDC and 0.06052 WETH at the current price
#   position  115259 in range [188400,202260]: 369.455 USDC and 0.111569 WETH at the current price
#   position  134968 in range [188400,202260]: 402.468 USDC and 0.121538 WETH at the current price
#   position  126413 in range [188400,202260]: 429.922 USDC and 0.129829 WETH at the current price
#   position  126467 in range [188400,202260]: 732.336 USDC and 0.221152 WETH at the current price
#   position  110882 in range [188400,202260]: 3262.63 USDC and 0.985254 WETH at the current price
#   position  126502 in range [188400,202260]: 4618.69 USDC and 1.39476 WETH at the current price
#   position  135054 in range [188400,202260]: 5010.96 USDC and 1.51322 WETH at the current price
#   position  115223 in range [188400,202260]: 5019.06 USDC and 1.51566 WETH at the current price
#   position  125533 in range [188460,202320]: 5.1074 USDC and 0.00152015 WETH at the current price
#   position  111214 in range [188460,202320]: 10.1782 USDC and 0.00302941 WETH at the current price
#   position  112608 in range [188460,202320]: 98.9413 USDC and 0.0294486 WETH at the current price
#   position  125117 in range [188460,202320]: 406.456 USDC and 0.120977 WETH at the current price
#   position  111046 in range [188460,202320]: 1086.05 USDC and 0.323248 WETH at the current price
#   position  109352 in range [188460,202320]: 2301.01 USDC and 0.684868 WETH at the current price
#   position  109536 in range [188460,202320]: 2392.81 USDC and 0.71219 WETH at the current price
#   position  127598 in range [188460,207240]: 157.89 USDC and 0.0309233 WETH at the current price
#   position  109356 in range [188520,197460]: 290.675 USDC and 0.249285 WETH at the current price
#   position  105805 in range [188520,198960]: 31340.1 USDC and 16.4157 WETH at the current price
#   position  125613 in range [188520,201960]: 2909.43 USDC and 0.898476 WETH at the current price
#   position  110387 in range [188520,202380]: 331.411 USDC and 0.0972211 WETH at the current price
#   position  112599 in range [188520,202380]: 980.709 USDC and 0.287696 WETH at the current price
#   position  114441 in range [188520,202440]: 515.506 USDC and 0.150165 WETH at the current price
#   position  111375 in range [188520,202440]: 3565.57 USDC and 1.03864 WETH at the current price
#   position  126104 in range [188520,203160]: 463031 USDC and 124.59 WETH at the current price
# ...
#   position  106973 in range [194700,196260]: 5945.74 USDC and 1.17393 WETH at the current price
#   position  108324 in range [194700,196260]: 22169.2 USDC and 4.37709 WETH at the current price
#   position  111237 in range [194700,196620]: 204.833 USDC and 0.0295738 WETH at the current price
#   position  133370 in range [194700,196920]: 56428.8 USDC and 6.67648 WETH at the current price
#   position  118834 in range [194700,197100]: 1494.37 USDC and 0.159717 WETH at the current price
#   position   33305 in range [194700,198000]: 13694 USDC and 0.995289 WETH at the current price
#   position   24339 in range [194700,198060]: 130.345 USDC and 0.00928029 WETH at the current price
#   position   30962 in range [194700,198060]: 170.807 USDC and 0.0121612 WETH at the current price
#   position   37207 in range [194700,198060]: 1454.28 USDC and 0.103542 WETH at the current price
#   position  111777 in range [194700,198060]: 3207.67 USDC and 0.22838 WETH at the current price
#   position  133043 in range [194700,198060]: 22177.7 USDC and 1.57901 WETH at the current price
#   position  107281 in range [194700,198360]: 757.114 USDC and 0.0489565 WETH at the current price
#   position   38041 in range [194700,198480]: 17013.5 USDC and 1.06155 WETH at the current price
#   position  133791 in range [194700,198480]: 165250 USDC and 10.3107 WETH at the current price
#   position   33039 in range [194700,198780]: 11319.8 USDC and 0.649921 WETH at the current price
#   position  107166 in range [194700,198900]: 49.9746 USDC and 0.00278139 WETH at the current price
#   position   25422 in range [194700,198900]: 92368.6 USDC and 5.14087 WETH at the current price
#   position   39420 in range [194700,199320]: 786.32 USDC and 0.0395778 WETH at the current price
#   position   29572 in range [194700,199380]: 756.382 USDC and 0.0375638 WETH at the current price
#   position   59029 in range [194700,200280]: 929.666 USDC and 0.038633 WETH at the current price
#   position   34164 in range [194700,200280]: 13763.8 USDC and 0.571965 WETH at the current price
#   position   30114 in range [194700,200340]: 364.119 USDC and 0.0149722 WETH at the current price
#   position   36944 in range [194700,200340]: 783.239 USDC and 0.032206 WETH at the current price
#   position   44113 in range [194700,200340]: 14497.7 USDC and 0.596132 WETH at the current price
#   position  103089 in range [194700,200400]: 49270.7 USDC and 2.00495 WETH at the current price
#   position   52974 in range [194700,200580]: 8256.69 USDC and 0.325906 WETH at the current price
#   position  110054 in range [194700,200820]: 1442.14 USDC and 0.0547562 WETH at the current price
#   position   79776 in range [194700,201360]: 3227.37 USDC and 0.113042 WETH at the current price
#   position   58408 in range [194700,201360]: 8862 USDC and 0.3104 WETH at the current price
#   position   46846 in range [194700,201660]: 8178.6 USDC and 0.274873 WETH at the current price
#   position   23297 in range [194700,201780]: 1576.91 USDC and 0.0521627 WETH at the current price
#   position   66005 in range [194700,201900]: 1391.97 USDC and 0.0453347 WETH at the current price
#   position   76074 in range [194700,201960]: 5526.14 USDC and 0.178609 WETH at the current price
#   position   18830 in range [194700,201960]: 159098 USDC and 5.14216 WETH at the current price
#   position   28879 in range [194700,202260]: 11797.3 USDC and 0.367423 WETH at the current price
#   position   20334 in range [194700,202860]: 7965.94 USDC and 0.231617 WETH at the current price
#   position   73376 in range [194700,203160]: 0.000220102 USDC and 6.19838e-09 WETH at the current price
#   position   82650 in range [194700,203160]: 82.2584 USDC and 0.00231652 WETH at the current price
#   position   22544 in range [194700,203160]: 1298.58 USDC and 0.0365699 WETH at the current price
#   position   52628 in range [194700,203160]: 42042.7 USDC and 1.18398 WETH at the current price
#   position   33950 in range [194700,203160]: 64785.1 USDC and 1.82444 WETH at the current price
#   position   49640 in range [194700,203160]: 810186 USDC and 22.816 WETH at the current price
#   position   94932 in range [194700,203880]: 8.4808 USDC and 0.000222462 WETH at the current price
#   position   19929 in range [194700,205440]: 41127.4 USDC and 0.946079 WETH at the current price
#   position   37118 in range [194700,207240]: 373.734 USDC and 0.00760449 WETH at the current price
#   position   21553 in range [194700,207240]: 11497.4 USDC and 0.233941 WETH at the current price
#   position   90638 in range [194700,208560]: 1944.57 USDC and 0.0366932 WETH at the current price
#   position    1255 in range [194700,276300]: 1.25579 USDC and 1.16815e-05 WETH at the current price
#   position  134921 in range [194760,195360]: 213425 USDC and 735.113 WETH at the current price
#   position  123495 in range [194760,195840]: 3391.24 USDC and 1.07466 WETH at the current price
#   position  118712 in range [194760,196320]: 4445.99 USDC and 0.74685 WETH at the current price
#   position  111663 in range [194760,196860]: 1428.03 USDC and 0.158304 WETH at the current price
#   position   18606 in range [194760,198120]: 26768.1 USDC and 1.68725 WETH at the current price
#   position  101971 in range [194760,202380]: 20.4551 USDC and 0.000567298 WETH at the current price
#   position  130761 in range [194760,202680]: 179846 USDC and 4.81857 WETH at the current price
#   position   97475 in range [194760,203160]: 1107.55 USDC and 0.0281744 WETH at the current price
#   position   26159 in range [194760,204960]: 180452 USDC and 3.89312 WETH at the current price
#   position   90617 in range [194760,208620]: 198.16 USDC and 0.00336692 WETH at the current price
#   position  111768 in range [194820,195720]: 83.6869 USDC and 0.0305437 WETH at the current price
#   position  114795 in range [194820,196020]: 20.616 USDC and 0.00436855 WETH at the current price
#   position  111697 in range [194820,196080]: 80.9827 USDC and 0.0158433 WETH at the current price
#   position    7762 in range [194820,196200]: 6.39777 USDC and 0.00108573 WETH at the current price
#   position  106835 in range [194820,196920]: 904.874 USDC and 0.0863268 WETH at the current price
#   position  132075 in range [194820,196920]: 11689 USDC and 1.11516 WETH at the current price
#   position  132456 in range [194820,197940]: 780.319 USDC and 0.0467056 WETH at the current price
#   position   24987 in range [194820,198960]: 6386.73 USDC and 0.282313 WETH at the current price
#   position  133560 in range [194820,199560]: 70527.2 USDC and 2.71631 WETH at the current price
#   position   40502 in range [194820,202020]: 2.78621e+06 USDC and 72.064 WETH at the current price
#   position   90612 in range [194820,208680]: 240.461 USDC and 0.00363547 WETH at the current price
#   position  109173 in range [194880,195480]: 185.075 USDC and 0.143394 WETH at the current price
#   position  131377 in range [194880,196740]: 21264.7 USDC and 1.99992 WETH at the current price
#   position  112437 in range [194880,196920]: 706.383 USDC and 0.0592605 WETH at the current price
#   position  114317 in range [194880,197100]: 1827.84 USDC and 0.138518 WETH at the current price
#   position  131617 in range [194880,197640]: 31810.1 USDC and 1.87621 WETH at the current price
#   position  131964 in range [194880,197640]: 48278.6 USDC and 2.84755 WETH at the current price
#   position  134404 in range [194880,197640]: 410587 USDC and 24.2171 WETH at the current price
#   position  133034 in range [194880,197940]: 145300 USDC and 7.64769 WETH at the current price
#   position  132279 in range [194880,198540]: 40886.6 USDC and 1.77784 WETH at the current price
#   position   63432 in range [194880,201600]: 2034.04 USDC and 0.0488651 WETH at the current price
#   position  115423 in range [194940,196200]: 145.939 USDC and 0.018782 WETH at the current price
#   position  134112 in range [194940,196920]: 6551.07 USDC and 0.473965 WETH at the current price
#   position  130328 in range [194940,198480]: 47038.9 USDC and 1.7947 WETH at the current price
#   position  109272 in range [194940,198900]: 36961 USDC and 1.25789 WETH at the current price
#   position   22633 in range [194940,200340]: 899.255 USDC and 0.0226106 WETH at the current price
#   position  128358 in range [195000,195600]: 128495 USDC and 42.1945 WETH at the current price
#   position  125057 in range [195000,195780]: 4178.89 USDC and 0.848254 WETH at the current price
#   position  118867 in range [195000,195900]: 113.018 USDC and 0.0183138 WETH at the current price
#   position  118256 in range [195000,196620]: 1659.35 USDC and 0.123054 WETH at the current price
#   position  108074 in range [195000,196620]: 32320.2 USDC and 2.39679 WETH at the current price
#   position   22190 in range [195000,197160]: 129585 USDC and 6.89288 WETH at the current price
#   position  131759 in range [195000,197520]: 4653.77 USDC and 0.209025 WETH at the current price
#   position  131879 in range [195000,197760]: 146886 USDC and 5.9857 WETH at the current price
#   position  130330 in range [195000,198480]: 54379.7 USDC and 1.74274 WETH at the current price
#   position  130493 in range [195000,198480]: 65248.5 USDC and 2.09106 WETH at the current price
#   position   25402 in range [195000,198540]: 82299.9 USDC and 2.59227 WETH at the current price
#   position  106155 in range [195000,198600]: 3742.75 USDC and 0.115907 WETH at the current price
#   position   39290 in range [195000,198660]: 18984 USDC and 0.578207 WETH at the current price
#   position   40045 in range [195000,198900]: 264.027 USDC and 0.00754758 WETH at the current price
#   position   37916 in range [195000,199380]: 1679.91 USDC and 0.0428512 WETH at the current price
#   position   23006 in range [195000,200280]: 5533.63 USDC and 0.118111 WETH at the current price
#   position   75877 in range [195000,200340]: 704.905 USDC and 0.0148875 WETH at the current price
#   position   48716 in range [195000,200760]: 3536.84 USDC and 0.0696344 WETH at the current price
#   position   53214 in range [195000,200820]: 363.647 USDC and 0.00709176 WETH at the current price
#   position  109362 in range [195000,214140]: 487716 USDC and 3.75402 WETH at the current price
#   position  115635 in range [195060,196020]: 48.6401 USDC and 0.00531081 WETH at the current price
#   position  111601 in range [195060,196320]: 3972.39 USDC and 0.30692 WETH at the current price
#   position  108224 in range [195060,196440]: 62968.5 USDC and 4.36053 WETH at the current price
#   position  117173 in range [195060,196500]: 26.6618 USDC and 0.00175567 WETH at the current price
#   position  110237 in range [195060,196920]: 9339.92 USDC and 0.459128 WETH at the current price
#   position  123747 in range [195060,196920]: 41616 USDC and 2.04574 WETH at the current price
#   position  130807 in range [195060,197040]: 18273.5 USDC and 0.838377 WETH at the current price
#   position  131970 in range [195060,197520]: 17958.1 USDC and 0.652451 WETH at the current price
#   position  132122 in range [195060,197640]: 23150.8 USDC and 0.800108 WETH at the current price
#   position  131984 in range [195060,198180]: 51479.6 USDC and 1.46338 WETH at the current price
#   position   22399 in range [195060,200340]: 10598.8 USDC and 0.181068 WETH at the current price
#   position  130778 in range [195120,197220]: 68594 USDC and 2.18446 WETH at the current price
#   position  130780 in range [195120,197220]: 647165 USDC and 20.6098 WETH at the current price
#   position  133630 in range [195120,197340]: 42193.7 USDC and 1.26794 WETH at the current price
#   position  108891 in range [195120,203160]: 118266 USDC and 1.05586 WETH at the current price
#   position  117050 in range [195180,195480]: 2864.56 USDC and 0.683252 WETH at the current price
#   position  134841 in range [195180,195720]: 114566 USDC and 11.3195 WETH at the current price
#   position  118851 in range [195180,195780]: 808.368 USDC and 0.069734 WETH at the current price
#   position  119727 in range [195180,196080]: 28.2071 USDC and 0.00149389 WETH at the current price
#   position  119495 in range [195180,196260]: 1285.57 USDC and 0.0554049 WETH at the current price
#   position  133799 in range [195180,197520]: 8065.66 USDC and 0.153958 WETH at the current price
#   position   47330 in range [195180,200280]: 105.818 USDC and 0.000959858 WETH at the current price
#   position   46904 in range [195180,200340]: 23.0803 USDC and 0.000207158 WETH at the current price
#   position   25877 in range [195180,200340]: 34.7947 USDC and 0.000312301 WETH at the current price
#   position  131839 in range [195180,201360]: 563.214 USDC and 0.00430606 WETH at the current price
#   position   72720 in range [195180,201900]: 222.943 USDC and 0.00158494 WETH at the current price
#   position   72843 in range [195180,202140]: 336.427 USDC and 0.00232077 WETH at the current price
#   position   94855 in range [195180,202680]: 161.349 USDC and 0.00104464 WETH at the current price
#   position    9365 in range [195180,253320]: 4.7666 USDC and 1.00633e-05 WETH at the current price
#   position    4329 in range [195180,276300]: 0.993306 USDC and 2.01688e-06 WETH at the current price
#   position  134706 in range [195240,195660]: 24985.9 USDC and 1.57873 WETH at the current price
#   position    6732 in range [195240,196140]: 1.83667 USDC and 4.93603e-05 WETH at the current price
#   position  108033 in range [195240,196440]: 1458.06 USDC and 0.0289785 WETH at the current price
#   position   33167 in range [195240,198780]: 9178.19 USDC and 0.0628355 WETH at the current price
#   position   22229 in range [195240,199380]: 2309.65 USDC and 0.0136774 WETH at the current price
#   position   22017 in range [195240,199860]: 10687.3 USDC and 0.0572673 WETH at the current price
#   position  113176 in range [195240,200160]: 4307.11 USDC and 0.0218079 WETH at the current price
#   position  133657 in range [195240,201420]: 188.045 USDC and 0.00077877 WETH at the current price
#   position  102108 in range [195240,201420]: 1572.14 USDC and 0.00651088 WETH at the current price
#   position   71787 in range [195240,202260]: 444086 USDC and 1.64922 WETH at the current price
#   position   89805 in range [195240,203280]: 82.7664 USDC and 0.000274513 WETH at the current price
#   position   83017 in range [195240,207300]: 3.86568 USDC and 9.34477e-06 WETH at the current price
#   position  119397 in range [195300,195660]: 0.0908429 USDC and 9.58084e-07 WETH at the current price
#   position  132395 in range [195300,195900]: 21969.4 USDC and 0.137952 WETH at the current price
#   position  109280 in range [195300,196260]: 62121.7 USDC and 0.244122 WETH at the current price
#   position  118409 in range [195300,196500]: 193.743 USDC and 0.00061117 WETH at the current price
#   position  135034 in range [195300,196620]: 9457.88 USDC and 0.0271787 WETH at the current price
#   position  105902 in range [195300,196620]: 1.03357e+07 USDC and 29.7013 WETH at the current price
#   position  131607 in range [195300,197220]: 6396.73 USDC and 0.0127894 WETH at the current price
#   position  132504 in range [195300,197340]: 12356.8 USDC and 0.0233126 WETH at the current price
#   position   24886 in range [195300,199380]: 282.571 USDC and 0.000279308 WETH at the current price
#   position  104760 in range [195300,200100]: 183.161 USDC and 0.000156511 WETH at the current price
#   position   46938 in range [195300,200340]: 283.582 USDC and 0.000232086 WETH at the current price
#   position   37415 in range [195300,200340]: 561.505 USDC and 0.000459539 WETH at the current price
#   position   36725 in range [195300,200340]: 1022.94 USDC and 0.000837184 WETH at the current price
#   position   47479 in range [195300,200340]: 5497.82 USDC and 0.00449945 WETH at the current price
#   position   22643 in range [195300,200340]: 399364 USDC and 0.326842 WETH at the current price
#   position   48757 in range [195300,201360]: 657.257 USDC and 0.000458196 WETH at the current price
# In total (including inactive positions): 1.03556e+08 USDC and 29527.1 WETH
# Total liquidity from active positions: 13668847079325344406, from pool: 14036798240673091886 (should be equal...)
